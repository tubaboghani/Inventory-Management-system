# %%
import json

fd=open("record.json",'r')
r=fd.read()
fd.close()

record=json.loads(r)

record
# Out:
# {'1001': {'Mfg.date': '1-20',
#   'company_name': 'britania',
#   'name': 'Choco Cake',
#   'pr': 100,
#   'qn': 330},
#  '1002': {'Mfg.date': '2-21',
#   'company_name': 'britania',
#   'name': 'Milk Cake',
#   'pr': 800,
#   'qn': 95},
#  '1003': {'Mfg.date': '1-19',
#   'company_name': 'pepsi',
#   'name': 'Drink',
#   'pr': 85,
#   'qn': 100},
#  '1004': {'Mfg.date': '4-20',
#   'company_name': 'britania',
#   'name': 'Candy',
#   'pr': 5,
#   'qn': 987},
#  '1005': {'Mfg.date': '6-21',
#   'company_name': 'cello',
#   'name': 'Pen',
#   'pr': 20,
#   'qn': 100},
#  '1006': {'Mfg.date': '11-20',
#   'company_name': 'realme',
#   'name': 'Phone',
#   'pr': 50000,
#   'qn': 10},
#  '1007': {'Mfg.date': '3-21',
#   'company_name': 'sony',
#   'name': 'Mic',
#   'pr': 1500,
#   'qn': 56},
#  '1008': {'Mfg.date': '8-20',
#   'company_name': 'sony',
#   'name': 'Case',
#   'pr': 599,
#   'qn': 4},
#  '1009': {'Mfg.date': '10-20',
#   'company_name': 'dell',
#   'name': 'Keyboard',
#   'pr': 1999,
#   'qn': 10},
#  '1010': {'Mfg.date': '11-20',
#   'company_name': 'sony',
#   'name': 'headphones',
#   'pr': 200,
#   'qn': 24},
#  '1011': {'Mfg.date': '12-20',
#   'company_name': 'apsara',
#   'name': 'pencil',
#   'pr': 5,
#   'qn': 100},
#  '1012': {'Mfg.date': '7-20',
#   'company_name': 'lays',
#   'name': 'chips',
#   'pr': 20,
#   'qn': 150},
#  '1013': {'Mfg.date': '8-20',
#   'company_name': 'vim',
#   'name': 'soap',
#   'pr': 15,
#   'qn': 200},
#  '1014': {'Mfg.date': '10-20',
#   'company_name': 'kitkat',
#   'name': 'kitkat',
#   'pr': 30,
#   'qn': 350},
#  '1015': {'Mfg.date': '5-20',
#   'company_name': 'sundaram',
#   'name': 'notebook',
#   'pr': 45,
#   'qn': 385},
#  '1016': {'Mfg.date': '2-20',
#   'company_name': 'classmate',
#   'name': 'rubber',
#   'pr': 5,
#   'qn': 20},
#  '1017': {'Mfg.date': '8-20',
#   'company_name': 'britania',
#   'name': 'biscuits',
#   'pr': 40,
#   'qn': 38},
#  '1018': {'Mfg.date': '11-20',
#   'company_name': 'kinley',
#   'name': 'bottle',
#   'pr': 60,
#   'qn': 500},
#  '1019': {'Mfg.date': '1-20',
#   'company_name': 'nirma',
#   'name': 'washing powder',
#   'pr': 300,
#   'qn': 95},
#  '1020': {'Mfg.date': '8-20',
#   'company_name': 'sony',
#   'name': 'charger',
#   'pr': 350,
#   'qn': 90},
#  '1021': {'Mfg.date': '7-20',
#   'company_name': 'gucci',
#   'name': 'wallet',
#   'pr': 199,
#   'qn': 183},
#  '1022': {'Mfg.date': '9-20',
#   'company_name': 'classmate',
#   'name': 'scale',
#   'pr': 10,
#   'qn': 30},
#  '1023': {'Mfg.date': '3-20',
#   'company_name': 'classmate',
#   'name': 'sharpener',
#   'pr': 5,
#   'qn': 398},
#  '1024': {'Mfg.date': '2-21',
#   'company_name': 'sundaram',
#   'name': 'textbook',
#   'pr': 150,
#   'qn': 77},
#  '1025': {'Mfg.date': '1-21',
#   'company_name': 'classmate',
#   'name': 'graph paper',
#   'pr': 2,
#   'qn': 165},
#  '1026': {'Mfg.date': '12-20',
#   'company_name': 'fevicol',
#   'name': 'fevicol',
#   'pr': 15,
#   'qn': 30},
#  '1027': {'Mfg.date': '11-20',
#   'company_name': 'classmate',
#   'name': 'scissor',
#   'pr': 25,
#   'qn': 40},
#  '1028': {'Mfg.date': '9-20',
#   'company_name': 'vaselin',
#   'name': 'cream',
#   'pr': 99,
#   'qn': 9},
#  '1029': {'Mfg.date': '7-20',
#   'company_name': 'ponds',
#   'name': 'powder',
#   'pr': 299,
#   'qn': 300},
#  '1030': {'Mfg.date': '5-20',
#   'company_name': 'hp',
#   'name': 'laptop',
#   'pr': 40000,
#   'qn': 2},
#  '1031': {'Mfg.date': '3-20',
#   'company_name': 'adidas',
#   'name': 'basket',
#   'pr': 45,
#   'qn': 100},
#  '1032': {'Mfg.date': '1-21',
#   'company_name': 'adidas',
#   'name': 'bucket',
#   'pr': 89,
#   'qn': 15},
#  '1033': {'Mfg.date': '3-20',
#   'company_name': 'lakme',
#   'name': 'lipstick',
#   'pr': 200,
#   'qn': 104},
#  '1034': {'Mfg.date': '5-20',
#   'company_name': 'huda',
#   'name': 'eyeliner',
#   'pr': 89,
#   'qn': 45},
#  '1035': {'Mfg.date': '7-21',
#   'company_name': 'adidas',
#   'name': 'jacket',
#   'pr': 400,
#   'qn': 13}}

# %%
import time
sales={}

no=int(input("enter a no of products u sold: "))


for i in range(1,no+1):
   no= int(input("enter a key number : "))
   ui_prod=str(input("enter a product id: "))
   ui_quant=int(input("enter a quantity : "))
  
   if record[ui_prod]['qn'] >= ui_quant :
       print("name: ",record[ui_prod]['name'])
       print ("amount : ",record[ui_prod]['pr']*ui_quant)

       sales[no]={'prod': ui_prod, 'qn': ui_quant, 'amount': record[ui_prod]['pr']*ui_quant, 'name': record[ui_prod]['name'], 'time': time.ctime()}
   
    
       record[ui_prod]['qn']=record[ui_prod]['qn'] - ui_quant
   else:
      print("sorry,such qunatity is not avialable\n")   
    
print("total sales made")
# Out:
# enter a no of products u sold: 10
# enter a key number : 1
# enter a product id: 1002
# enter a quantity : 5
# name:  Milk Cake
# amount :  4000
# enter a key number : 2
# enter a product id: 1004
# enter a quantity : 1
# name:  Candy
# amount :  5
# enter a key number : 3
# enter a product id: 1035
# enter a quantity : 7
# name:  jacket
# amount :  2800
# enter a key number : 4
# enter a product id: 1019
# enter a quantity : 5
# name:  washing powder
# amount :  1500
# enter a key number : 5
# enter a product id: 1007
# enter a quantity : 4
# name:  Mic
# amount :  6000
# enter a key number : 6
# enter a product id: 1024
# enter a quantity : 3
# name:  textbook
# amount :  450
# enter a key number : 7
# enter a product id: 1028
# enter a quantity : 1
# name:  cream
# amount :  99
# enter a key number : 8
# enter a product id: 1034
# enter a quantity : 5
# name:  eyeliner
# amount :  445
# enter a key number : 9
# enter a product id: 1023
# enter a quantity : 2
# name:  sharpener
# amount :  10
# enter a key number : 10
# enter a product id: 1010
# enter a quantity : 1
# name:  headphones
# amount :  200
# total sales made

# %%
json.dumps(sales)
# Out:
# '{"1": {"prod": "1002", "qn": 5, "amount": 4000, "name": "Milk Cake", "time": "Sun Sep  5 16:07:04 2021"}, "2": {"prod": "1004", "qn": 1, "amount": 5, "name": "Candy", "time": "Sun Sep  5 16:07:18 2021"}, "3": {"prod": "1035", "qn": 7, "amount": 2800, "name": "jacket", "time": "Sun Sep  5 16:07:31 2021"}, "4": {"prod": "1019", "qn": 5, "amount": 1500, "name": "washing powder", "time": "Sun Sep  5 16:07:42 2021"}, "5": {"prod": "1007", "qn": 4, "amount": 6000, "name": "Mic", "time": "Sun Sep  5 16:08:01 2021"}, "6": {"prod": "1024", "qn": 3, "amount": 450, "name": "textbook", "time": "Sun Sep  5 16:08:20 2021"}, "7": {"prod": "1028", "qn": 1, "amount": 99, "name": "cream", "time": "Sun Sep  5 16:08:36 2021"}, "8": {"prod": "1034", "qn": 5, "amount": 445, "name": "eyeliner", "time": "Sun Sep  5 16:08:50 2021"}, "9": {"prod": "1023", "qn": 2, "amount": 10, "name": "sharpener", "time": "Sun Sep  5 16:09:07 2021"}, "10": {"prod": "1010", "qn": 1, "amount": 200, "name": "headphones", "time": "Sun Sep  5 16:09:26 2021"}}'

# %%
js=json.dumps(sales)

fd=open("sales.json",'w')
r=fd.write(js)
fd.close()

# %%
js=json.dumps(record)

fd=open("record.json",'w')
fd.write(js)
fd.close()
